# %% [markdown]
# <a href="https://colab.research.google.com/github/WeizmannMLcourse/homework1-ariels1234/blob/main/homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Quantum Parameters Estimation with Neural Networks

# %%
# Enabling access to the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Creating a path to my drive for importing the relevant modules
import sys
import os
root_path = "/content/drive/MyDrive/GitHub/Project_CNN/"
sys.path.append(os.path.abspath(root_path))

# %%
# Unzipping the Dateset file from the google drive
# !unzip '/content/drive/MyDrive/GitHub/Project/Dataset.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Dataset/validation/repetition=1 omega=1  gamma=1 delta=1 serial=0.npy
#   inflating: Dataset/validation/repetition=1 omega=1  gamma=10 delta=1 serial=9.npy
#   inflating: Dataset/validation/repetition=1 omega=1  gamma=2 delta=1 serial=1.npy
#   inflating: Dataset/validation/repetition=1 omega=1  gamma=3 delta=1 serial=2.npy
#   inflating: Dataset/validation/repetition=1 omega=1  gamma=4 delta=1 serial=3.npy
#   inflating: Dataset/validation/repetition=1 omega=1  gamma=5 delta=1 serial=4.npy
#   inflating: Dataset/validation/repetition=1 omega=1  gamma=6 delta=1 serial=5.npy
#   inflating: Dataset/validation/repetition=1 omega=1  gamma=7 delta=1 serial=6.npy
#   inflating: Dataset/validation/repetition=1 omega=1  gamma=8 delta=1 serial=7.npy
#   inflating: Dataset/validation/repetition=1 omega=1  gamma=9 delta=1 serial=8.npy
#   inflating: Dataset/validation/repetition=1 omega=10  gamma=1 delta=1 serial=90.npy
#   inflating: Dataset/validation/repetition=1 omega=10  gamma=10 delta=1 serial=99.npy
#   inflating: Dataset/validation/repetition=1 omega=10  gamma=2 delta=1 serial=91.npy
#   inflating: Dataset/validation/repetition=1 omega=10  gamma=3 delta=1 serial=92.npy
#   inflating: Dataset/validation/repetition=1 omega=10  gamma=4 delta=1 serial=93.npy
#   inflating: Dataset/validation/repetition=1 omega=10  gamma=5 delta=1 serial=94.npy
#   inflating: Dataset/validation/repetition=1 omega=10  gamma=6 delta=1 serial=95.npy
#   inflating: Dataset/validation/repetition=1 omega=10  gamma=7 delta=1 serial=96.npy
#   inflating: Dataset/validation/repetition=1 omega=10  gamma=8 delta=1 serial=97.npy
#   inflating: Dataset/validation/repetition=1 omega=10  gamma=9 delta=1 serial=98.npy
#   inflating: Dataset/validation/repetition=1 omega=2  gamma=1 delta=1 serial=10.npy
#   inflating: Dataset/validation/repetition=1 omega=2  gamma=10 delta=1 serial=19.npy
#   inflating: Dataset/validation/repetition=1 omega=2  gamma=2 delta=1 serial=11.npy
#   inflating: Dataset/validation/repetition=1 omega=2  gamma=3 delta=1 serial=12.npy
#   inflating: Dataset/validation/repetition=1 omega=2  gamma=4 delta=1 serial=13.npy
#   inflating: Dataset/validation/repetition=1 omega=2  gamma=5 delta=1 serial=14.npy
#   inflating: Dataset/validation/repetition=1 omega=2  gamma=6 delta=1 serial=15.npy
#   inflating: Dataset/validation/repetition=1 omega=2  gamma=7 delta=1 serial=16.npy
#   inflating: Dataset/validation/repetition=1 omega=2  gamma=8 delta=1 serial=17.npy
#   inflating: Dataset/validation/repetition=1 omega=2  gamma=9 delta=1 serial=18.npy
#   inflating: Dataset/validation/repetition=1 omega=3  gamma=1 delta=1 serial=20.npy
#   inflating: Dataset/validation/repetition=1 omega=3  gamma=10 delta=1 serial=29.npy
#   inflating: Dataset/validation/repetition=1 omega=3  gamma=2 delta=1 serial=21.npy
#   inflating: Dataset/validation/repetition=1 omega=3  gamma=3 delta=1 serial=22.npy
#   inflating: Dataset/validation/repetition=1 omega=3  gamma=4 delta=1 serial=23.npy
#   inflating: Dataset/validation/repetition=1 omega=3  gamma=5 delta=1 serial=24.npy
#   inflating: Dataset/validation/repetition=1 omega=3  gamma=6 delta=1 serial=25.npy
#   inflating: Dataset/validation/repetition=1 omega=3  gamma=7 delta=1 serial=26.npy
#   inflating: Dataset/validation/repetition=1 omega=3  gamma=8 delta=1 serial=27.npy
#   inflating: Dataset/validation/repetition=1 omega=3  gamma=9 delta=1 serial=28.npy
#   inflating: Dataset/validation/repetition=1 omega=4  gamma=1 delta=1 serial=30.npy
#   inflating: Dataset/validation/repetition=1 omega=4  gamma=10 delta=1 serial=39.npy
#   inflating: Dataset/validation/repetition=1 omega=4  gamma=2 delta=1 serial=31.npy
#   inflating: Dataset/validation/repetition=1 omega=4  gamma=3 delta=1 serial=32.npy
#   inflating: Dataset/validation/repetition=1 omega=4  gamma=4 delta=1 serial=33.npy
#   inflating: Dataset/validation/repetition=1 omega=4  gamma=5 delta=1 serial=34.npy
#   inflating: Dataset/validation/repetition=1 omega=4  gamma=6 delta=1 serial=35.npy
#   inflating: Dataset/validation/repetition=1 omega=4  gamma=7 delta=1 serial=36.npy
#   inflating: Dataset/validation/repetition=1 omega=4  gamma=8 delta=1 serial=37.npy
#   inflating: Dataset/validation/repetition=1 omega=4  gamma=9 delta=1 serial=38.npy
#   inflating: Dataset/validation/repetition=1 omega=5  gamma=1 delta=1 serial=40.npy
#   inflating: Dataset/validation/repetition=1 omega=5  gamma=10 delta=1 serial=49.npy
#   inflating: Dataset/validation/repetition=1 omega=5  gamma=2 delta=1 serial=41.npy
#   inflating: Dataset/validation/repetition=1 omega=5  gamma=3 delta=1 serial=42.npy
#   inflating: Dataset/validation/repetition=1 omega=5  gamma=4 delta=1 serial=43.npy
#   inflating: Dataset/validation/repetition=1 omega=5  gamma=5 delta=1 serial=44.npy
#   inflating: Dataset/validation/repetition=1 omega=5  gamma=6 delta=1 serial=45.npy
#   inflating: Dataset/validation/repetition=1 omega=5  gamma=7 delta=1 serial=46.npy
#   inflating: Dataset/validation/repetition=1 omega=5  gamma=8 delta=1 serial=47.npy
#   inflating: Dataset/validation/repetition=1 omega=5  gamma=9 delta=1 serial=48.npy
#   inflating: Dataset/validation/repetition=1 omega=6  gamma=1 delta=1 serial=50.npy
#   inflating: Dataset/validation/repetition=1 omega=6  gamma=10 delta=1 serial=59.npy
#   inflating: Dataset/validation/repetition=1 omega=6  gamma=2 delta=1 serial=51.npy
#   inflating: Dataset/validation/repetition=1 omega=6  gamma=3 delta=1 serial=52.npy
#   inflating: Dataset/validation/repetition=1 omega=6  gamma=4 delta=1 serial=53.npy
#   inflating: Dataset/validation/repetition=1 omega=6  gamma=5 delta=1 serial=54.npy
#   inflating: Dataset/validation/repetition=1 omega=6  gamma=6 delta=1 serial=55.npy
#   inflating: Dataset/validation/repetition=1 omega=6  gamma=7 delta=1 serial=56.npy
#   inflating: Dataset/validation/repetition=1 omega=6  gamma=8 delta=1 serial=57.npy
#   inflating: Dataset/validation/repetition=1 omega=6  gamma=9 delta=1 serial=58.npy
#   inflating: Dataset/validation/repetition=1 omega=7  gamma=1 delta=1 serial=60.npy
#   inflating: Dataset/validation/repetition=1 omega=7  gamma=10 delta=1 serial=69.npy
#   inflating: Dataset/validation/repetition=1 omega=7  gamma=2 delta=1 serial=61.npy
#   inflating: Dataset/validation/repetition=1 omega=7  gamma=3 delta=1 serial=62.npy
#   inflating: Dataset/validation/repetition=1 omega=7  gamma=4 delta=1 serial=63.npy
#   inflating: Dataset/validation/repetition=1 omega=7  gamma=5 delta=1 serial=64.npy
#   inflating: Dataset/validation/repetition=1 omega=7  gamma=6 delta=1 serial=65.npy
#   inflating: Dataset/validation/repetition=1 omega=7  gamma=7 delta=1 serial=66.npy
#   inflating: Dataset/validation/repetition=1 omega=7  gamma=8 delta=1 serial=67.npy
#   inflating: Dataset/validation/repetition=1 omega=7  gamma=9 delta=1 serial=68.npy
#   inflating: Dataset/validation/repetition=1 omega=8  gamma=1 delta=1 serial=70.npy
#   inflating: Dataset/validation/repetition=1 omega=8  gamma=10 delta=1 serial=79.npy
#   inflating: Dataset/validation/repetition=1 omega=8  gamma=2 delta=1 serial=71.npy
#   inflating: Dataset/validation/repetition=1 omega=8  gamma=3 delta=1 serial=72.npy
#   inflating: Dataset/validation/repetition=1 omega=8  gamma=4 delta=1 serial=73.npy
#   inflating: Dataset/validation/repetition=1 omega=8  gamma=5 delta=1 serial=74.npy
#   inflating: Dataset/validation/repetition=1 omega=8  gamma=6 delta=1 serial=75.npy
#   inflating: Dataset/validation/repetition=1 omega=8  gamma=7 delta=1 serial=76.npy
#   inflating: Dataset/validation/repetition=1 omega=8  gamma=8 delta=1 serial=77.npy
#   inflating: Dataset/validation/repetition=1 omega=8  gamma=9 delta=1 serial=78.npy
#   inflating: Dataset/validation/repetition=1 omega=9  gamma=1 delta=1 serial=80.npy
#   inflating: Dataset/validation/repetition=1 omega=9  gamma=10 delta=1 serial=89.npy
#   inflating: Dataset/validation/repetition=1 omega=9  gamma=2 delta=1 serial=81.npy
#   inflating: Dataset/validation/repetition=1 omega=9  gamma=3 delta=1 serial=82.npy
#   inflating: Dataset/validation/repetition=1 omega=9  gamma=4 delta=1 serial=83.npy
#   inflating: Dataset/validation/repetition=1 omega=9  gamma=5 delta=1 serial=84.npy
#   inflating: Dataset/validation/repetition=1 omega=9  gamma=6 delta=1 serial=85.npy
#   inflating: Dataset/validation/repetition=1 omega=9  gamma=7 delta=1 serial=86.npy
#   inflating: Dataset/validation/repetition=1 omega=9  gamma=8 delta=1 serial=87.npy
#   inflating: Dataset/validation/repetition=1 omega=9  gamma=9 delta=1 serial=88.npy
#   inflating: Dataset/validation/repetition=10 omega=1  gamma=1 delta=1 serial=0.npy
#   inflating: Dataset/validation/repetition=10 omega=1  gamma=10 delta=1 serial=9.npy
#   inflating: Dataset/validation/repetition=10 omega=1  gamma=2 delta=1 serial=1.npy
#   inflating: Dataset/validation/repetition=10 omega=1  gamma=3 delta=1 serial=2.npy
#   inflating: Dataset/validation/repetition=10 omega=1  gamma=4 delta=1 serial=3.npy
#   inflating: Dataset/validation/repetition=10 omega=1  gamma=5 delta=1 serial=4.npy
#   inflating: Dataset/validation/repetition=10 omega=1  gamma=6 delta=1 serial=5.npy
#   inflating: Dataset/validation/repetition=10 omega=1  gamma=7 delta=1 serial=6.npy
#   inflating: Dataset/validation/repetition=10 omega=1  gamma=8 delta=1 serial=7.npy
#   inflating: Dataset/validation/repetition=10 omega=1  gamma=9 delta=1 serial=8.npy
#   inflating: Dataset/validation/repetition=10 omega=10  gamma=1 delta=1 serial=90.npy
#   inflating: Dataset/validation/repetition=10 omega=10  gamma=10 delta=1 serial=99.npy
#   inflating: Dataset/validation/repetition=10 omega=10  gamma=2 delta=1 serial=91.npy
#   inflating: Dataset/validation/repetition=10 omega=10  gamma=3 delta=1 serial=92.npy
#   inflating: Dataset/validation/repetition=10 omega=10  gamma=4 delta=1 serial=93.npy
#   inflating: Dataset/validation/repetition=10 omega=10  gamma=5 delta=1 serial=94.npy
#   inflating: Dataset/validation/repetition=10 omega=10  gamma=6 delta=1 serial=95.npy
#   inflating: Dataset/validation/repetition=10 omega=10  gamma=7 delta=1 serial=96.npy
#   inflating: Dataset/validation/repetition=10 omega=10  gamma=8 delta=1 serial=97.npy
#   inflating: Dataset/validation/repetition=10 omega=10  gamma=9 delta=1 serial=98.npy
#   inflating: Dataset/validation/repetition=10 omega=2  gamma=1 delta=1 serial=10.npy
#   inflating: Dataset/validation/repetition=10 omega=2  gamma=10 delta=1 serial=19.npy
#   inflating: Dataset/validation/repetition=10 omega=2  gamma=2 delta=1 serial=11.npy
#   inflating: Dataset/validation/repetition=10 omega=2  gamma=3 delta=1 serial=12.npy
#   inflating: Dataset/validation/repetition=10 omega=2  gamma=4 delta=1 serial=13.npy
#   inflating: Dataset/validation/repetition=10 omega=2  gamma=5 delta=1 serial=14.npy
#   inflating: Dataset/validation/repetition=10 omega=2  gamma=6 delta=1 serial=15.npy
#   inflating: Dataset/validation/repetition=10 omega=2  gamma=7 delta=1 serial=16.npy
#   inflating: Dataset/validation/repetition=10 omega=2  gamma=8 delta=1 serial=17.npy
#   inflating: Dataset/validation/repetition=10 omega=2  gamma=9 delta=1 serial=18.npy
#   inflating: Dataset/validation/repetition=10 omega=3  gamma=1 delta=1 serial=20.npy
#   inflating: Dataset/validation/repetition=10 omega=3  gamma=10 delta=1 serial=29.npy
#   inflating: Dataset/validation/repetition=10 omega=3  gamma=2 delta=1 serial=21.npy
#   inflating: Dataset/validation/repetition=10 omega=3  gamma=3 delta=1 serial=22.npy
#   inflating: Dataset/validation/repetition=10 omega=3  gamma=4 delta=1 serial=23.npy
#   inflating: Dataset/validation/repetition=10 omega=3  gamma=5 delta=1 serial=24.npy
#   inflating: Dataset/validation/repetition=10 omega=3  gamma=6 delta=1 serial=25.npy
#   inflating: Dataset/validation/repetition=10 omega=3  gamma=7 delta=1 serial=26.npy
#   inflating: Dataset/validation/repetition=10 omega=3  gamma=8 delta=1 serial=27.npy
#   inflating: Dataset/validation/repetition=10 omega=3  gamma=9 delta=1 serial=28.npy
#   inflating: Dataset/validation/repetition=10 omega=4  gamma=1 delta=1 serial=30.npy
#   inflating: Dataset/validation/repetition=10 omega=4  gamma=10 delta=1 serial=39.npy
#   inflating: Dataset/validation/repetition=10 omega=4  gamma=2 delta=1 serial=31.npy
#   inflating: Dataset/validation/repetition=10 omega=4  gamma=3 delta=1 serial=32.npy
#   inflating: Dataset/validation/repetition=10 omega=4  gamma=4 delta=1 serial=33.npy
#   inflating: Dataset/validation/repetition=10 omega=4  gamma=5 delta=1 serial=34.npy
#   inflating: Dataset/validation/repetition=10 omega=4  gamma=6 delta=1 serial=35.npy
#   inflating: Dataset/validation/repetition=10 omega=4  gamma=7 delta=1 serial=36.npy
#   inflating: Dataset/validation/repetition=10 omega=4  gamma=8 delta=1 serial=37.npy
#   inflating: Dataset/validation/repetition=10 omega=4  gamma=9 delta=1 serial=38.npy
#   inflating: Dataset/validation/repetition=10 omega=5  gamma=1 delta=1 serial=40.npy
#   inflating: Dataset/validation/repetition=10 omega=5  gamma=10 delta=1 serial=49.npy
#   inflating: Dataset/validation/repetition=10 omega=5  gamma=2 delta=1 serial=41.npy
#   inflating: Dataset/validation/repetition=10 omega=5  gamma=3 delta=1 serial=42.npy
#   inflating: Dataset/validation/repetition=10 omega=5  gamma=4 delta=1 serial=43.npy
#   inflating: Dataset/validation/repetition=10 omega=5  gamma=5 delta=1 serial=44.npy
#   inflating: Dataset/validation/repetition=10 omega=5  gamma=6 delta=1 serial=45.npy
#   inflating: Dataset/validation/repetition=10 omega=5  gamma=7 delta=1 serial=46.npy
#   inflating: Dataset/validation/repetition=10 omega=5  gamma=8 delta=1 serial=47.npy
#   inflating: Dataset/validation/repetition=10 omega=5  gamma=9 delta=1 serial=48.npy
#   inflating: Dataset/validation/repetition=10 omega=6  gamma=1 delta=1 serial=50.npy
#   inflating: Dataset/validation/repetition=10 omega=6  gamma=10 delta=1 serial=59.npy
#   inflating: Dataset/validation/repetition=10 omega=6  gamma=2 delta=1 serial=51.npy
#   inflating: Dataset/validation/repetition=10 omega=6  gamma=3 delta=1 serial=52.npy
#   inflating: Dataset/validation/repetition=10 omega=6  gamma=4 delta=1 serial=53.npy
#   inflating: Dataset/validation/repetition=10 omega=6  gamma=5 delta=1 serial=54.npy
#   inflating: Dataset/validation/repetition=10 omega=6  gamma=6 delta=1 serial=55.npy
#   inflating: Dataset/validation/repetition=10 omega=6  gamma=7 delta=1 serial=56.npy
#   inflating: Dataset/validation/repetition=10 omega=6  gamma=8 delta=1 serial=57.npy
#   inflating: Dataset/validation/repetition=10 omega=6  gamma=9 delta=1 serial=58.npy
#   inflating: Dataset/validation/repetition=10 omega=7  gamma=1 delta=1 serial=60.npy
#   inflating: Dataset/validation/repetition=10 omega=7  gamma=10 delta=1 serial=69.npy
#   inflating: Dataset/validation/repetition=10 omega=7  gamma=2 delta=1 serial=61.npy
#   inflating: Dataset/validation/repetition=10 omega=7  gamma=3 delta=1 serial=62.npy
#   inflating: Dataset/validation/repetition=10 omega=7  gamma=4 delta=1 serial=63.npy
#   inflating: Dataset/validation/repetition=10 omega=7  gamma=5 delta=1 serial=64.npy
#   inflating: Dataset/validation/repetition=10 omega=7  gamma=6 delta=1 serial=65.npy
#   inflating: Dataset/validation/repetition=10 omega=7  gamma=7 delta=1 serial=66.npy
#   inflating: Dataset/validation/repetition=10 omega=7  gamma=8 delta=1 serial=67.npy
#   inflating: Dataset/validation/repetition=10 omega=7  gamma=9 delta=1 serial=68.npy
#   inflating: Dataset/validation/repetition=10 omega=8  gamma=1 delta=1 serial=70.npy
#   inflating: Dataset/validation/repetition=10 omega=8  gamma=10 delta=1 serial=79.npy
#   inflating: Dataset/validation/repetition=10 omega=8  gamma=2 delta=1 serial=71.npy
#   inflating: Dataset/validation/repetition=10 omega=8  gamma=3 delta=1 serial=72.npy
#   inflating: Dataset/validation/repetition=10 omega=8  gamma=4 delta=1 serial=73.npy
#   inflating: Dataset/validation/repetition=10 omega=8  gamma=5 delta=1 serial=74.npy
#   inflating: Dataset/validation/repetition=10 omega=8  gamma=6 delta=1 serial=75.npy
#   inflating: Dataset/validation/repetition=10 omega=8  gamma=7 delta=1 serial=76.npy
#   inflating: Dataset/validation/repetition=10 omega=8  gamma=8 delta=1 serial=77.npy
#   inflating: Dataset/validation/repetition=10 omega=8  gamma=9 delta=1 serial=78.npy
#   inflating: Dataset/validation/repetition=10 omega=9  gamma=1 delta=1 serial=80.npy
#   inflating: Dataset/validation/repetition=10 omega=9  gamma=10 delta=1 serial=89.npy
#   inflating: Dataset/validation/repetition=10 omega=9  gamma=2 delta=1 serial=81.npy
#   inflating: Dataset/validation/repetition=10 omega=9  gamma=3 delta=1 serial=82.npy
#   inflating: Dataset/validation/repetition=10 omega=9  gamma=4 delta=1 serial=83.npy
#   inflating: Dataset/validation/repetition=10 omega=9  gamma=5 delta=1 serial=84.npy
#   inflating: Dataset/validation/repetition=10 omega=9  gamma=6 delta=1 serial=85.npy
#   inflating: Dataset/validation/repetition=10 omega=9  gamma=7 delta=1 serial=86.npy
#   inflating: Dataset/validation/repetition=10 omega=9  gamma=8 delta=1 serial=87.npy
#   inflating: Dataset/validation/repetition=10 omega=9  gamma=9 delta=1 serial=88.npy
#   inflating: Dataset/validation/repetition=11 omega=1  gamma=1 delta=1 serial=0.npy
#   inflating: Dataset/validation/repetition=11 omega=1  gamma=10 delta=1 serial=9.npy
#   inflating: Dataset/validation/repetition=11 omega=1  gamma=2 delta=1 serial=1.npy
#   inflating: Dataset/validation/repetition=11 omega=1  gamma=3 delta=1 serial=2.npy
#   inflating: Dataset/validation/repetition=11 omega=1  gamma=4 delta=1 serial=3.npy
#   inflating: Dataset/validation/repetition=11 omega=1  gamma=5 delta=1 serial=4.npy
#   inflating: Dataset/validation/repetition=11 omega=1  gamma=6 delta=1 serial=5.npy
#   inflating: Dataset/validation/repetition=11 omega=1  gamma=7 delta=1 serial=6.npy
#   inflating: Dataset/validation/repetition=11 omega=1  gamma=8 delta=1 serial=7.npy
#   inflating: Dataset/validation/repetition=11 omega=1  gamma=9 delta=1 serial=8.npy
#   inflating: Dataset/validation/repetition=11 omega=10  gamma=1 delta=1 serial=90.npy
#   inflating: Dataset/validation/repetition=11 omega=10  gamma=10 delta=1 serial=99.npy
#   inflating: Dataset/validation/repetition=11 omega=10  gamma=2 delta=1 serial=91.npy
#   inflating: Dataset/validation/repetition=11 omega=10  gamma=3 delta=1 serial=92.npy
#   inflating: Dataset/validation/repetition=11 omega=10  gamma=4 delta=1 serial=93.npy
#   inflating: Dataset/validation/repetition=11 omega=10  gamma=5 delta=1 serial=94.npy
#   inflating: Dataset/validation/repetition=11 omega=10  gamma=6 delta=1 serial=95.npy
#   inflating: Dataset/validation/repetition=11 omega=10  gamma=7 delta=1 serial=96.npy
#   inflating: Dataset/validation/repetition=11 omega=10  gamma=8 delta=1 serial=97.npy
#   inflating: Dataset/validation/repetition=11 omega=10  gamma=9 delta=1 serial=98.npy
#   inflating: Dataset/validation/repetition=11 omega=2  gamma=1 delta=1 serial=10.npy
#   inflating: Dataset/validation/repetition=11 omega=2  gamma=10 delta=1 serial=19.npy
#   inflating: Dataset/validation/repetition=11 omega=2  gamma=2 delta=1 serial=11.npy
#   inflating: Dataset/validation/repetition=11 omega=2  gamma=3 delta=1 serial=12.npy
#   inflating: Dataset/validation/repetition=11 omega=2  gamma=4 delta=1 serial=13.npy
#   inflating: Dataset/validation/repetition=11 omega=2  gamma=5 delta=1 serial=14.npy
#   inflating: Dataset/validation/repetition=11 omega=2  gamma=6 delta=1 serial=15.npy
#   inflating: Dataset/validation/repetition=11 omega=2  gamma=7 delta=1 serial=16.npy
#   inflating: Dataset/validation/repetition=11 omega=2  gamma=8 delta=1 serial=17.npy
#   inflating: Dataset/validation/repetition=11 omega=2  gamma=9 delta=1 serial=18.npy
#   inflating: Dataset/validation/repetition=11 omega=3  gamma=1 delta=1 serial=20.npy
#   inflating: Dataset/validation/repetition=11 omega=3  gamma=10 delta=1 serial=29.npy
#   inflating: Dataset/validation/repetition=11 omega=3  gamma=2 delta=1 serial=21.npy
#   inflating: Dataset/validation/repetition=11 omega=3  gamma=3 delta=1 serial=22.npy
#   inflating: Dataset/validation/repetition=11 omega=3  gamma=4 delta=1 serial=23.npy
#   inflating: Dataset/validation/repetition=11 omega=3  gamma=5 delta=1 serial=24.npy
#   inflating: Dataset/validation/repetition=11 omega=3  gamma=6 delta=1 serial=25.npy
#   inflating: Dataset/validation/repetition=11 omega=3  gamma=7 delta=1 serial=26.npy
#   inflating: Dataset/validation/repetition=11 omega=3  gamma=8 delta=1 serial=27.npy
#   inflating: Dataset/validation/repetition=11 omega=3  gamma=9 delta=1 serial=28.npy
#   inflating: Dataset/validation/repetition=11 omega=4  gamma=1 delta=1 serial=30.npy
#   inflating: Dataset/validation/repetition=11 omega=4  gamma=10 delta=1 serial=39.npy
#   inflating: Dataset/validation/repetition=11 omega=4  gamma=2 delta=1 serial=31.npy
#   inflating: Dataset/validation/repetition=11 omega=4  gamma=3 delta=1 serial=32.npy
#   inflating: Dataset/validation/repetition=11 omega=4  gamma=4 delta=1 serial=33.npy
#   inflating: Dataset/validation/repetition=11 omega=4  gamma=5 delta=1 serial=34.npy
#   inflating: Dataset/validation/repetition=11 omega=4  gamma=6 delta=1 serial=35.npy
#   inflating: Dataset/validation/repetition=11 omega=4  gamma=7 delta=1 serial=36.npy
#   inflating: Dataset/validation/repetition=11 omega=4  gamma=8 delta=1 serial=37.npy
#   inflating: Dataset/validation/repetition=11 omega=4  gamma=9 delta=1 serial=38.npy
#   inflating: Dataset/validation/repetition=11 omega=5  gamma=1 delta=1 serial=40.npy
#   inflating: Dataset/validation/repetition=11 omega=5  gamma=10 delta=1 serial=49.npy
#   inflating: Dataset/validation/repetition=11 omega=5  gamma=2 delta=1 serial=41.npy
#   inflating: Dataset/validation/repetition=11 omega=5  gamma=3 delta=1 serial=42.npy
#   inflating: Dataset/validation/repetition=11 omega=5  gamma=4 delta=1 serial=43.npy
#   inflating: Dataset/validation/repetition=11 omega=5  gamma=5 delta=1 serial=44.npy
#   inflating: Dataset/validation/repetition=11 omega=5  gamma=6 delta=1 serial=45.npy
#   inflating: Dataset/validation/repetition=11 omega=5  gamma=7 delta=1 serial=46.npy
#   inflating: Dataset/validation/repetition=11 omega=5  gamma=8 delta=1 serial=47.npy
#   inflating: Dataset/validation/repetition=11 omega=5  gamma=9 delta=1 serial=48.npy
#   inflating: Dataset/validation/repetition=11 omega=6  gamma=1 delta=1 serial=50.npy
#   inflating: Dataset/validation/repetition=11 omega=6  gamma=10 delta=1 serial=59.npy
#   inflating: Dataset/validation/repetition=11 omega=6  gamma=2 delta=1 serial=51.npy
#   inflating: Dataset/validation/repetition=11 omega=6  gamma=3 delta=1 serial=52.npy
#   inflating: Dataset/validation/repetition=11 omega=6  gamma=4 delta=1 serial=53.npy
#   inflating: Dataset/validation/repetition=11 omega=6  gamma=5 delta=1 serial=54.npy
#   inflating: Dataset/validation/repetition=11 omega=6  gamma=6 delta=1 serial=55.npy
#   inflating: Dataset/validation/repetition=11 omega=6  gamma=7 delta=1 serial=56.npy
#   inflating: Dataset/validation/repetition=11 omega=6  gamma=8 delta=1 serial=57.npy
#   inflating: Dataset/validation/repetition=11 omega=6  gamma=9 delta=1 serial=58.npy
#   inflating: Dataset/validation/repetition=11 omega=7  gamma=1 delta=1 serial=60.npy
#   inflating: Dataset/validation/repetition=11 omega=7  gamma=10 delta=1 serial=69.npy
#   inflating: Dataset/validation/repetition=11 omega=7  gamma=2 delta=1 serial=61.npy
#   inflating: Dataset/validation/repetition=11 omega=7  gamma=3 delta=1 serial=62.npy
#   inflating: Dataset/validation/repetition=11 omega=7  gamma=4 delta=1 serial=63.npy
#   inflating: Dataset/validation/repetition=11 omega=7  gamma=5 delta=1 serial=64.npy
#   inflating: Dataset/validation/repetition=11 omega=7  gamma=6 delta=1 serial=65.npy
#   inflating: Dataset/validation/repetition=11 omega=7  gamma=7 delta=1 serial=66.npy
#   inflating: Dataset/validation/repetition=11 omega=7  gamma=8 delta=1 serial=67.npy
#   inflating: Dataset/validation/repetition=11 omega=7  gamma=9 delta=1 serial=68.npy
#   inflating: Dataset/validation/repetition=11 omega=8  gamma=1 delta=1 serial=70.npy
#   inflating: Dataset/validation/repetition=11 omega=8  gamma=10 delta=1 serial=79.npy
#   inflating: Dataset/validation/repetition=11 omega=8  gamma=2 delta=1 serial=71.npy
#   inflating: Dataset/validation/repetition=11 omega=8  gamma=3 delta=1 serial=72.npy
#   inflating: Dataset/validation/repetition=11 omega=8  gamma=4 delta=1 serial=73.npy
#   inflating: Dataset/validation/repetition=11 omega=8  gamma=5 delta=1 serial=74.npy
#   inflating: Dataset/validation/repetition=11 omega=8  gamma=6 delta=1 serial=75.npy
#   inflating: Dataset/validation/repetition=11 omega=8  gamma=7 delta=1 serial=76.npy
#   inflating: Dataset/validation/repetition=11 omega=8  gamma=8 delta=1 serial=77.npy
#   inflating: Dataset/validation/repetition=11 omega=8  gamma=9 delta=1 serial=78.npy
#   inflating: Dataset/validation/repetition=11 omega=9  gamma=1 delta=1 serial=80.npy
#   inflating: Dataset/validation/repetition=11 omega=9  gamma=10 delta=1 serial=89.npy
#   inflating: Dataset/validation/repetition=11 omega=9  gamma=2 delta=1 serial=81.npy
#   inflating: Dataset/validation/repetition=11 omega=9  gamma=3 delta=1 serial=82.npy
#   inflating: Dataset/validation/repetition=11 omega=9  gamma=4 delta=1 serial=83.npy
#   inflating: Dataset/validation/repetition=11 omega=9  gamma=5 delta=1 serial=84.npy
#   inflating: Dataset/validation/repetition=11 omega=9  gamma=6 delta=1 serial=85.npy
#   inflating: Dataset/validation/repetition=11 omega=9  gamma=7 delta=1 serial=86.npy
#   inflating: Dataset/validation/repetition=11 omega=9  gamma=8 delta=1 serial=87.npy
#   inflating: Dataset/validation/repetition=11 omega=9  gamma=9 delta=1 serial=88.npy
#   inflating: Dataset/validation/repetition=12 omega=1  gamma=1 delta=1 serial=0.npy
#   inflating: Dataset/validation/repetition=12 omega=1  gamma=10 delta=1 serial=9.npy
#   inflating: Dataset/validation/repetition=12 omega=1  gamma=2 delta=1 serial=1.npy
#   inflating: Dataset/validation/repetition=12 omega=1  gamma=3 delta=1 serial=2.npy
#   inflating: Dataset/validation/repetition=12 omega=1  gamma=4 delta=1 serial=3.npy
#   inflating: Dataset/validation/repetition=12 omega=1  gamma=5 delta=1 serial=4.npy
#   inflating: Dataset/validation/repetition=12 omega=1  gamma=6 delta=1 serial=5.npy
#   inflating: Dataset/validation/repetition=12 omega=1  gamma=7 delta=1 serial=6.npy
#   inflating: Dataset/validation/repetition=12 omega=1  gamma=8 delta=1 serial=7.npy
#   inflating: Dataset/validation/repetition=12 omega=1  gamma=9 delta=1 serial=8.npy
#   inflating: Dataset/validation/repetition=12 omega=10  gamma=1 delta=1 serial=90.npy
#   inflating: Dataset/validation/repetition=12 omega=10  gamma=10 delta=1 serial=99.npy
#   inflating: Dataset/validation/repetition=12 omega=10  gamma=2 delta=1 serial=91.npy
#   inflating: Dataset/validation/repetition=12 omega=10  gamma=3 delta=1 serial=92.npy
#   inflating: Dataset/validation/repetition=12 omega=10  gamma=4 delta=1 serial=93.npy
#   inflating: Dataset/validation/repetition=12 omega=10  gamma=5 delta=1 serial=94.npy
#   inflating: Dataset/validation/repetition=12 omega=10  gamma=6 delta=1 serial=95.npy
#   inflating: Dataset/validation/repetition=12 omega=10  gamma=7 delta=1 serial=96.npy
#   inflating: Dataset/validation/repetition=12 omega=10  gamma=8 delta=1 serial=97.npy
#   inflating: Dataset/validation/repetition=12 omega=10  gamma=9 delta=1 serial=98.npy
#   inflating: Dataset/validation/repetition=12 omega=2  gamma=1 delta=1 serial=10.npy
#   inflating: Dataset/validation/repetition=12 omega=2  gamma=10 delta=1 serial=19.npy
#   inflating: Dataset/validation/repetition=12 omega=2  gamma=2 delta=1 serial=11.npy
#   inflating: Dataset/validation/repetition=12 omega=2  gamma=3 delta=1 serial=12.npy
#   inflating: Dataset/validation/repetition=12 omega=2  gamma=4 delta=1 serial=13.npy
#   inflating: Dataset/validation/repetition=12 omega=2  gamma=5 delta=1 serial=14.npy
#   inflating: Dataset/validation/repetition=12 omega=2  gamma=6 delta=1 serial=15.npy
#   inflating: Dataset/validation/repetition=12 omega=2  gamma=7 delta=1 serial=16.npy
#   inflating: Dataset/validation/repetition=12 omega=2  gamma=8 delta=1 serial=17.npy
#   inflating: Dataset/validation/repetition=12 omega=2  gamma=9 delta=1 serial=18.npy
#   inflating: Dataset/validation/repetition=12 omega=3  gamma=1 delta=1 serial=20.npy
#   inflating: Dataset/validation/repetition=12 omega=3  gamma=10 delta=1 serial=29.npy
#   inflating: Dataset/validation/repetition=12 omega=3  gamma=2 delta=1 serial=21.npy
#   inflating: Dataset/validation/repetition=12 omega=3  gamma=3 delta=1 serial=22.npy
#   inflating: Dataset/validation/repetition=12 omega=3  gamma=4 delta=1 serial=23.npy
#   inflating: Dataset/validation/repetition=12 omega=3  gamma=5 delta=1 serial=24.npy
#   inflating: Dataset/validation/repetition=12 omega=3  gamma=6 delta=1 serial=25.npy
#   inflating: Dataset/validation/repetition=12 omega=3  gamma=7 delta=1 serial=26.npy
#   inflating: Dataset/validation/repetition=12 omega=3  gamma=8 delta=1 serial=27.npy
#   inflating: Dataset/validation/repetition=12 omega=3  gamma=9 delta=1 serial=28.npy
#   inflating: Dataset/validation/repetition=12 omega=4  gamma=1 delta=1 serial=30.npy
#   inflating: Dataset/validation/repetition=12 omega=4  gamma=10 delta=1 serial=39.npy
#   inflating: Dataset/validation/repetition=12 omega=4  gamma=2 delta=1 serial=31.npy
#   inflating: Dataset/validation/repetition=12 omega=4  gamma=3 delta=1 serial=32.npy
#   inflating: Dataset/validation/repetition=12 omega=4  gamma=4 delta=1 serial=33.npy
#   inflating: Dataset/validation/repetition=12 omega=4  gamma=5 delta=1 serial=34.npy
#   inflating: Dataset/validation/repetition=12 omega=4  gamma=6 delta=1 serial=35.npy
#   inflating: Dataset/validation/repetition=12 omega=4  gamma=7 delta=1 serial=36.npy
#   inflating: Dataset/validation/repetition=12 omega=4  gamma=8 delta=1 serial=37.npy
#   inflating: Dataset/validation/repetition=12 omega=4  gamma=9 delta=1 serial=38.npy
#   inflating: Dataset/validation/repetition=12 omega=5  gamma=1 delta=1 serial=40.npy
#   inflating: Dataset/validation/repetition=12 omega=5  gamma=10 delta=1 serial=49.npy
#   inflating: Dataset/validation/repetition=12 omega=5  gamma=2 delta=1 serial=41.npy
#   inflating: Dataset/validation/repetition=12 omega=5  gamma=3 delta=1 serial=42.npy
#   inflating: Dataset/validation/repetition=12 omega=5  gamma=4 delta=1 serial=43.npy
#   inflating: Dataset/validation/repetition=12 omega=5  gamma=5 delta=1 serial=44.npy
#   inflating: Dataset/validation/repetition=12 omega=5  gamma=6 delta=1 serial=45.npy
#   inflating: Dataset/validation/repetition=12 omega=5  gamma=7 delta=1 serial=46.npy
#   inflating: Dataset/validation/repetition=12 omega=5  gamma=8 delta=1 serial=47.npy
#   inflating: Dataset/validation/repetition=12 omega=5  gamma=9 delta=1 serial=48.npy
#   inflating: Dataset/validation/repetition=12 omega=6  gamma=1 delta=1 serial=50.npy
#   inflating: Dataset/validation/repetition=12 omega=6  gamma=10 delta=1 serial=59.npy
#   inflating: Dataset/validation/repetition=12 omega=6  gamma=2 delta=1 serial=51.npy
#   inflating: Dataset/validation/repetition=12 omega=6  gamma=3 delta=1 serial=52.npy
#   inflating: Dataset/validation/repetition=12 omega=6  gamma=4 delta=1 serial=53.npy
#   inflating: Dataset/validation/repetition=12 omega=6  gamma=5 delta=1 serial=54.npy
#   inflating: Dataset/validation/repetition=12 omega=6  gamma=6 delta=1 serial=55.npy
#   inflating: Dataset/validation/repetition=12 omega=6  gamma=7 delta=1 serial=56.npy
#   inflating: Dataset/validation/repetition=12 omega=6  gamma=8 delta=1 serial=57.npy
#   inflating: Dataset/validation/repetition=12 omega=6  gamma=9 delta=1 serial=58.npy
#   inflating: Dataset/validation/repetition=12 omega=7  gamma=1 delta=1 serial=60.npy
#   inflating: Dataset/validation/repetition=12 omega=7  gamma=10 delta=1 serial=69.npy
#   inflating: Dataset/validation/repetition=12 omega=7  gamma=2 delta=1 serial=61.npy
#   inflating: Dataset/validation/repetition=12 omega=7  gamma=3 delta=1 serial=62.npy
#   inflating: Dataset/validation/repetition=12 omega=7  gamma=4 delta=1 serial=63.npy
#   inflating: Dataset/validation/repetition=12 omega=7  gamma=5 delta=1 serial=64.npy
#   inflating: Dataset/validation/repetition=12 omega=7  gamma=6 delta=1 serial=65.npy
#   inflating: Dataset/validation/repetition=12 omega=7  gamma=7 delta=1 serial=66.npy
#   inflating: Dataset/validation/repetition=12 omega=7  gamma=8 delta=1 serial=67.npy
#   inflating: Dataset/validation/repetition=12 omega=7  gamma=9 delta=1 serial=68.npy
#   inflating: Dataset/validation/repetition=12 omega=8  gamma=1 delta=1 serial=70.npy
#   inflating: Dataset/validation/repetition=12 omega=8  gamma=10 delta=1 serial=79.npy
#   inflating: Dataset/validation/repetition=12 omega=8  gamma=2 delta=1 serial=71.npy
#   inflating: Dataset/validation/repetition=12 omega=8  gamma=3 delta=1 serial=72.npy
#   inflating: Dataset/validation/repetition=12 omega=8  gamma=4 delta=1 serial=73.npy
#   inflating: Dataset/validation/repetition=12 omega=8  gamma=5 delta=1 serial=74.npy
#   inflating: Dataset/validation/repetition=12 omega=8  gamma=6 delta=1 serial=75.npy
#   inflating: Dataset/validation/repetition=12 omega=8  gamma=7 delta=1 serial=76.npy
#   inflating: Dataset/validation/repetition=12 omega=8  gamma=8 delta=1 serial=77.npy
#   inflating: Dataset/validation/repetition=12 omega=8  gamma=9 delta=1 serial=78.npy
#   inflating: Dataset/validation/repetition=12 omega=9  gamma=1 delta=1 serial=80.npy
#   inflating: Dataset/validation/repetition=12 omega=9  gamma=10 delta=1 serial=89.npy
#   inflating: Dataset/validation/repetition=12 omega=9  gamma=2 delta=1 serial=81.npy
#   inflating: Dataset/validation/repetition=12 omega=9  gamma=3 delta=1 serial=82.npy
#   inflating: Dataset/validation/repetition=12 omega=9  gamma=4 delta=1 serial=83.npy
#   inflating: Dataset/validation/repetition=12 omega=9  gamma=5 delta=1 serial=84.npy
#   inflating: Dataset/validation/repetition=12 omega=9  gamma=6 delta=1 serial=85.npy
#   inflating: Dataset/validation/repetition=12 omega=9  gamma=7 delta=1 serial=86.npy
#   inflating: Dataset/validation/repetition=12 omega=9  gamma=8 delta=1 serial=87.npy
#   inflating: Dataset/validation/repetition=12 omega=9  gamma=9 delta=1 serial=88.npy
#   inflating: Dataset/validation/repetition=13 omega=1  gamma=1 delta=1 serial=0.npy
#   inflating: Dataset/validation/repetition=13 omega=1  gamma=10 delta=1 serial=9.npy
#   inflating: Dataset/validation/repetition=13 omega=1  gamma=2 delta=1 serial=1.npy
#   inflating: Dataset/validation/repetition=13 omega=1  gamma=3 delta=1 serial=2.npy
#   inflating: Dataset/validation/repetition=13 omega=1  gamma=4 delta=1 serial=3.npy
#   inflating: Dataset/validation/repetition=13 omega=1  gamma=5 delta=1 serial=4.npy
#   inflating: Dataset/validation/repetition=13 omega=1  gamma=6 delta=1 serial=5.npy
#   inflating: Dataset/validation/repetition=13 omega=1  gamma=7 delta=1 serial=6.npy
#   inflating: Dataset/validation/repetition=13 omega=1  gamma=8 delta=1 serial=7.npy
#   inflating: Dataset/validation/repetition=13 omega=1  gamma=9 delta=1 serial=8.npy
#   inflating: Dataset/validation/repetition=13 omega=10  gamma=1 delta=1 serial=90.npy
#   inflating: Dataset/validation/repetition=13 omega=10  gamma=10 delta=1 serial=99.npy
#   inflating: Dataset/validation/repetition=13 omega=10  gamma=2 delta=1 serial=91.npy
#   inflating: Dataset/validation/repetition=13 omega=10  gamma=3 delta=1 serial=92.npy
#   inflating: Dataset/validation/repetition=13 omega=10  gamma=4 delta=1 serial=93.npy
#   inflating: Dataset/validation/repetition=13 omega=10  gamma=5 delta=1 serial=94.npy
#   inflating: Dataset/validation/repetition=13 omega=10  gamma=6 delta=1 serial=95.npy
#   inflating: Dataset/validation/repetition=13 omega=10  gamma=7 delta=1 serial=96.npy
#   inflating: Dataset/validation/repetition=13 omega=10  gamma=8 delta=1 serial=97.npy
#   inflating: Dataset/validation/repetition=13 omega=10  gamma=9 delta=1 serial=98.npy
#   inflating: Dataset/validation/repetition=13 omega=2  gamma=1 delta=1 serial=10.npy
#   inflating: Dataset/validation/repetition=13 omega=2  gamma=10 delta=1 serial=19.npy
#   inflating: Dataset/validation/repetition=13 omega=2  gamma=2 delta=1 serial=11.npy
#   inflating: Dataset/validation/repetition=13 omega=2  gamma=3 delta=1 serial=12.npy
#   inflating: Dataset/validation/repetition=13 omega=2  gamma=4 delta=1 serial=13.npy
#   inflating: Dataset/validation/repetition=13 omega=2  gamma=5 delta=1 serial=14.npy
#   inflating: Dataset/validation/repetition=13 omega=2  gamma=6 delta=1 serial=15.npy
#   inflating: Dataset/validation/repetition=13 omega=2  gamma=7 delta=1 serial=16.npy
#   inflating: Dataset/validation/repetition=13 omega=2  gamma=8 delta=1 serial=17.npy
#   inflating: Dataset/validation/repetition=13 omega=2  gamma=9 delta=1 serial=18.npy
#   inflating: Dataset/validation/repetition=13 omega=3  gamma=1 delta=1 serial=20.npy
#   inflating: Dataset/validation/repetition=13 omega=3  gamma=10 delta=1 serial=29.npy
#   inflating: Dataset/validation/repetition=13 omega=3  gamma=2 delta=1 serial=21.npy
#   inflating: Dataset/validation/repetition=13 omega=3  gamma=3 delta=1 serial=22.npy
#   inflating: Dataset/validation/repetition=13 omega=3  gamma=4 delta=1 serial=23.npy
#   inflating: Dataset/validation/repetition=13 omega=3  gamma=5 delta=1 serial=24.npy
#   inflating: Dataset/validation/repetition=13 omega=3  gamma=6 delta=1 serial=25.npy
#   inflating: Dataset/validation/repetition=13 omega=3  gamma=7 delta=1 serial=26.npy
#   inflating: Dataset/validation/repetition=13 omega=3  gamma=8 delta=1 serial=27.npy
#   inflating: Dataset/validation/repetition=13 omega=3  gamma=9 delta=1 serial=28.npy
#   inflating: Dataset/validation/repetition=13 omega=4  gamma=1 delta=1 serial=30.npy
#   inflating: Dataset/validation/repetition=13 omega=4  gamma=10 delta=1 serial=39.npy
#   inflating: Dataset/validation/repetition=13 omega=4  gamma=2 delta=1 serial=31.npy
#   inflating: Dataset/validation/repetition=13 omega=4  gamma=3 delta=1 serial=32.npy
#   inflating: Dataset/validation/repetition=13 omega=4  gamma=4 delta=1 serial=33.npy
#   inflating: Dataset/validation/repetition=13 omega=4  gamma=5 delta=1 serial=34.npy
#   inflating: Dataset/validation/repetition=13 omega=4  gamma=6 delta=1 serial=35.npy
#   inflating: Dataset/validation/repetition=13 omega=4  gamma=7 delta=1 serial=36.npy
#   inflating: Dataset/validation/repetition=13 omega=4  gamma=8 delta=1 serial=37.npy
#   inflating: Dataset/validation/repetition=13 omega=4  gamma=9 delta=1 serial=38.npy
#   inflating: Dataset/validation/repetition=13 omega=5  gamma=1 delta=1 serial=40.npy
#   inflating: Dataset/validation/repetition=13 omega=5  gamma=10 delta=1 serial=49.npy
#   inflating: Dataset/validation/repetition=13 omega=5  gamma=2 delta=1 serial=41.npy
#   inflating: Dataset/validation/repetition=13 omega=5  gamma=3 delta=1 serial=42.npy
#   inflating: Dataset/validation/repetition=13 omega=5  gamma=4 delta=1 serial=43.npy
#   inflating: Dataset/validation/repetition=13 omega=5  gamma=5 delta=1 serial=44.npy
#   inflating: Dataset/validation/repetition=13 omega=5  gamma=6 delta=1 serial=45.npy
#   inflating: Dataset/validation/repetition=13 omega=5  gamma=7 delta=1 serial=46.npy
#   inflating: Dataset/validation/repetition=13 omega=5  gamma=8 delta=1 serial=47.npy
#   inflating: Dataset/validation/repetition=13 omega=5  gamma=9 delta=1 serial=48.npy
#   inflating: Dataset/validation/repetition=13 omega=6  gamma=1 delta=1 serial=50.npy
#   inflating: Dataset/validation/repetition=13 omega=6  gamma=10 delta=1 serial=59.npy
#   inflating: Dataset/validation/repetition=13 omega=6  gamma=2 delta=1 serial=51.npy
#   inflating: Dataset/validation/repetition=13 omega=6  gamma=3 delta=1 serial=52.npy
#   inflating: Dataset/validation/repetition=13 omega=6  gamma=4 delta=1 serial=53.npy
#   inflating: Dataset/validation/repetition=13 omega=6  gamma=5 delta=1 serial=54.npy
#   inflating: Dataset/validation/repetition=13 omega=6  gamma=6 delta=1 serial=55.npy
#   inflating: Dataset/validation/repetition=13 omega=6  gamma=7 delta=1 serial=56.npy
#   inflating: Dataset/validation/repetition=13 omega=6  gamma=8 delta=1 serial=57.npy
#   inflating: Dataset/validation/repetition=13 omega=6  gamma=9 delta=1 serial=58.npy
#   inflating: Dataset/validation/repetition=13 omega=7  gamma=1 delta=1 serial=60.npy
#   inflating: Dataset/validation/repetition=13 omega=7  gamma=10 delta=1 serial=69.npy
#   inflating: Dataset/validation/repetition=13 omega=7  gamma=2 delta=1 serial=61.npy
#   inflating: Dataset/validation/repetition=13 omega=7  gamma=3 delta=1 serial=62.npy
#   inflating: Dataset/validation/repetition=13 omega=7  gamma=4 delta=1 serial=63.npy
#   inflating: Dataset/validation/repetition=13 omega=7  gamma=5 delta=1 serial=64.npy
#   inflating: Dataset/validation/repetition=13 omega=7  gamma=6 delta=1 serial=65.npy
#   inflating: Dataset/validation/repetition=13 omega=7  gamma=7 delta=1 serial=66.npy
#   inflating: Dataset/validation/repetition=13 omega=7  gamma=8 delta=1 serial=67.npy
#   inflating: Dataset/validation/repetition=13 omega=7  gamma=9 delta=1 serial=68.npy
#   inflating: Dataset/validation/repetition=13 omega=8  gamma=1 delta=1 serial=70.npy
#   inflating: Dataset/validation/repetition=13 omega=8  gamma=10 delta=1 serial=79.npy
#   inflating: Dataset/validation/repetition=13 omega=8  gamma=2 delta=1 serial=71.npy
#   inflating: Dataset/validation/repetition=13 omega=8  gamma=3 delta=1 serial=72.npy
#   inflating: Dataset/validation/repetition=13 omega=8  gamma=4 delta=1 serial=73.npy
#   inflating: Dataset/validation/repetition=13 omega=8  gamma=5 delta=1 serial=74.npy
#   inflating: Dataset/validation/repetition=13 omega=8  gamma=6 delta=1 serial=75.npy
#   inflating: Dataset/validation/repetition=13 omega=8  gamma=7 delta=1 serial=76.npy
#   inflating: Dataset/validation/repetition=13 omega=8  gamma=8 delta=1 serial=77.npy
#   inflating: Dataset/validation/repetition=13 omega=8  gamma=9 delta=1 serial=78.npy
#   inflating: Dataset/validation/repetition=13 omega=9  gamma=1 delta=1 serial=80.npy
#   inflating: Dataset/validation/repetition=13 omega=9  gamma=10 delta=1 serial=89.npy
#   inflating: Dataset/validation/repetition=13 omega=9  gamma=2 delta=1 serial=81.npy
#   inflating: Dataset/validation/repetition=13 omega=9  gamma=3 delta=1 serial=82.npy
#   inflating: Dataset/validation/repetition=13 omega=9  gamma=4 delta=1 serial=83.npy
#   inflating: Dataset/validation/repetition=13 omega=9  gamma=5 delta=1 serial=84.npy
#   inflating: Dataset/validation/repetition=13 omega=9  gamma=6 delta=1 serial=85.npy
#   inflating: Dataset/validation/repetition=13 omega=9  gamma=7 delta=1 serial=86.npy
#   inflating: Dataset/validation/repetition=13 omega=9  gamma=8 delta=1 serial=87.npy
#   inflating: Dataset/validation/repetition=13 omega=9  gamma=9 delta=1 serial=88.npy
#   inflating: Dataset/validation/repetition=14 omega=1  gamma=1 delta=1 serial=0.npy
#   inflating: Dataset/validation/repetition=14 omega=1  gamma=10 delta=1 serial=9.npy
#   inflating: Dataset/validation/repetition=14 omega=1  gamma=2 delta=1 serial=1.npy
#   inflating: Dataset/validation/repetition=14 omega=1  gamma=3 delta=1 serial=2.npy
#   inflating: Dataset/validation/repetition=14 omega=1  gamma=4 delta=1 serial=3.npy
#   inflating: Dataset/validation/repetition=14 omega=1  gamma=5 delta=1 serial=4.npy
#   inflating: Dataset/validation/repetition=14 omega=1  gamma=6 delta=1 serial=5.npy
#   inflating: Dataset/validation/repetition=14 omega=1  gamma=7 delta=1 serial=6.npy
#   inflating: Dataset/validation/repetition=14 omega=1  gamma=8 delta=1 serial=7.npy
#   inflating: Dataset/validation/repetition=14 omega=1  gamma=9 delta=1 serial=8.npy
#   inflating: Dataset/validation/repetition=14 omega=10  gamma=1 delta=1 serial=90.npy
#   inflating: Dataset/validation/repetition=14 omega=10  gamma=10 delta=1 serial=99.npy
#   inflating: Dataset/validation/repetition=14 omega=10  gamma=2 delta=1 serial=91.npy
#   inflating: Dataset/validation/repetition=14 omega=10  gamma=3 delta=1 serial=92.npy
#   inflating: Dataset/validation/repetition=14 omega=10  gamma=4 delta=1 serial=93.npy
#   inflating: Dataset/validation/repetition=14 omega=10  gamma=5 delta=1 serial=94.npy
#   inflating: Dataset/validation/repetition=14 omega=10  gamma=6 delta=1 serial=95.npy
#   inflating: Dataset/validation/repetition=14 omega=10  gamma=7 delta=1 serial=96.npy
#   inflating: Dataset/validation/repetition=14 omega=10  gamma=8 delta=1 serial=97.npy
#   inflating: Dataset/validation/repetition=14 omega=10  gamma=9 delta=1 serial=98.npy
#   inflating: Dataset/validation/repetition=14 omega=2  gamma=1 delta=1 serial=10.npy
#   inflating: Dataset/validation/repetition=14 omega=2  gamma=10 delta=1 serial=19.npy
#   inflating: Dataset/validation/repetition=14 omega=2  gamma=2 delta=1 serial=11.npy
#   inflating: Dataset/validation/repetition=14 omega=2  gamma=3 delta=1 serial=12.npy
#   inflating: Dataset/validation/repetition=14 omega=2  gamma=4 delta=1 serial=13.npy
#   inflating: Dataset/validation/repetition=14 omega=2  gamma=5 delta=1 serial=14.npy
#   inflating: Dataset/validation/repetition=14 omega=2  gamma=6 delta=1 serial=15.npy
#   inflating: Dataset/validation/repetition=14 omega=2  gamma=7 delta=1 serial=16.npy
#   inflating: Dataset/validation/repetition=14 omega=2  gamma=8 delta=1 serial=17.npy
#   inflating: Dataset/validation/repetition=14 omega=2  gamma=9 delta=1 serial=18.npy
#   inflating: Dataset/validation/repetition=14 omega=3  gamma=1 delta=1 serial=20.npy
#   inflating: Dataset/validation/repetition=14 omega=3  gamma=10 delta=1 serial=29.npy
#   inflating: Dataset/validation/repetition=14 omega=3  gamma=2 delta=1 serial=21.npy
#   inflating: Dataset/validation/repetition=14 omega=3  gamma=3 delta=1 serial=22.npy
#   inflating: Dataset/validation/repetition=14 omega=3  gamma=4 delta=1 serial=23.npy
#   inflating: Dataset/validation/repetition=14 omega=3  gamma=5 delta=1 serial=24.npy
#   inflating: Dataset/validation/repetition=14 omega=3  gamma=6 delta=1 serial=25.npy
#   inflating: Dataset/validation/repetition=14 omega=3  gamma=7 delta=1 serial=26.npy
#   inflating: Dataset/validation/repetition=14 omega=3  gamma=8 delta=1 serial=27.npy
#   inflating: Dataset/validation/repetition=14 omega=3  gamma=9 delta=1 serial=28.npy
#   inflating: Dataset/validation/repetition=14 omega=4  gamma=1 delta=1 serial=30.npy
#   inflating: Dataset/validation/repetition=14 omega=4  gamma=10 delta=1 serial=39.npy
#   inflating: Dataset/validation/repetition=14 omega=4  gamma=2 delta=1 serial=31.npy
#   inflating: Dataset/validation/repetition=14 omega=4  gamma=3 delta=1 serial=32.npy
#   inflating: Dataset/validation/repetition=14 omega=4  gamma=4 delta=1 serial=33.npy
#   inflating: Dataset/validation/repetition=14 omega=4  gamma=5 delta=1 serial=34.npy
#   inflating: Dataset/validation/repetition=14 omega=4  gamma=6 delta=1 serial=35.npy
#   inflating: Dataset/validation/repetition=14 omega=4  gamma=7 delta=1 serial=36.npy
#   inflating: Dataset/validation/repetition=14 omega=4  gamma=8 delta=1 serial=37.npy
#   inflating: Dataset/validation/repetition=14 omega=4  gamma=9 delta=1 serial=38.npy
#   inflating: Dataset/validation/repetition=14 omega=5  gamma=1 delta=1 serial=40.npy
# ...
#   inflating: Dataset/validation/repetition=8 omega=10  gamma=5 delta=1 serial=94.npy
#   inflating: Dataset/validation/repetition=8 omega=10  gamma=6 delta=1 serial=95.npy
#   inflating: Dataset/validation/repetition=8 omega=10  gamma=7 delta=1 serial=96.npy
#   inflating: Dataset/validation/repetition=8 omega=10  gamma=8 delta=1 serial=97.npy
#   inflating: Dataset/validation/repetition=8 omega=10  gamma=9 delta=1 serial=98.npy
#   inflating: Dataset/validation/repetition=8 omega=2  gamma=1 delta=1 serial=10.npy
#   inflating: Dataset/validation/repetition=8 omega=2  gamma=10 delta=1 serial=19.npy
#   inflating: Dataset/validation/repetition=8 omega=2  gamma=2 delta=1 serial=11.npy
#   inflating: Dataset/validation/repetition=8 omega=2  gamma=3 delta=1 serial=12.npy
#   inflating: Dataset/validation/repetition=8 omega=2  gamma=4 delta=1 serial=13.npy
#   inflating: Dataset/validation/repetition=8 omega=2  gamma=5 delta=1 serial=14.npy
#   inflating: Dataset/validation/repetition=8 omega=2  gamma=6 delta=1 serial=15.npy
#   inflating: Dataset/validation/repetition=8 omega=2  gamma=7 delta=1 serial=16.npy
#   inflating: Dataset/validation/repetition=8 omega=2  gamma=8 delta=1 serial=17.npy
#   inflating: Dataset/validation/repetition=8 omega=2  gamma=9 delta=1 serial=18.npy
#   inflating: Dataset/validation/repetition=8 omega=3  gamma=1 delta=1 serial=20.npy
#   inflating: Dataset/validation/repetition=8 omega=3  gamma=10 delta=1 serial=29.npy
#   inflating: Dataset/validation/repetition=8 omega=3  gamma=2 delta=1 serial=21.npy
#   inflating: Dataset/validation/repetition=8 omega=3  gamma=3 delta=1 serial=22.npy
#   inflating: Dataset/validation/repetition=8 omega=3  gamma=4 delta=1 serial=23.npy
#   inflating: Dataset/validation/repetition=8 omega=3  gamma=5 delta=1 serial=24.npy
#   inflating: Dataset/validation/repetition=8 omega=3  gamma=6 delta=1 serial=25.npy
#   inflating: Dataset/validation/repetition=8 omega=3  gamma=7 delta=1 serial=26.npy
#   inflating: Dataset/validation/repetition=8 omega=3  gamma=8 delta=1 serial=27.npy
#   inflating: Dataset/validation/repetition=8 omega=3  gamma=9 delta=1 serial=28.npy
#   inflating: Dataset/validation/repetition=8 omega=4  gamma=1 delta=1 serial=30.npy
#   inflating: Dataset/validation/repetition=8 omega=4  gamma=10 delta=1 serial=39.npy
#   inflating: Dataset/validation/repetition=8 omega=4  gamma=2 delta=1 serial=31.npy
#   inflating: Dataset/validation/repetition=8 omega=4  gamma=3 delta=1 serial=32.npy
#   inflating: Dataset/validation/repetition=8 omega=4  gamma=4 delta=1 serial=33.npy
#   inflating: Dataset/validation/repetition=8 omega=4  gamma=5 delta=1 serial=34.npy
#   inflating: Dataset/validation/repetition=8 omega=4  gamma=6 delta=1 serial=35.npy
#   inflating: Dataset/validation/repetition=8 omega=4  gamma=7 delta=1 serial=36.npy
#   inflating: Dataset/validation/repetition=8 omega=4  gamma=8 delta=1 serial=37.npy
#   inflating: Dataset/validation/repetition=8 omega=4  gamma=9 delta=1 serial=38.npy
#   inflating: Dataset/validation/repetition=8 omega=5  gamma=1 delta=1 serial=40.npy
#   inflating: Dataset/validation/repetition=8 omega=5  gamma=10 delta=1 serial=49.npy
#   inflating: Dataset/validation/repetition=8 omega=5  gamma=2 delta=1 serial=41.npy
#   inflating: Dataset/validation/repetition=8 omega=5  gamma=3 delta=1 serial=42.npy
#   inflating: Dataset/validation/repetition=8 omega=5  gamma=4 delta=1 serial=43.npy
#   inflating: Dataset/validation/repetition=8 omega=5  gamma=5 delta=1 serial=44.npy
#   inflating: Dataset/validation/repetition=8 omega=5  gamma=6 delta=1 serial=45.npy
#   inflating: Dataset/validation/repetition=8 omega=5  gamma=7 delta=1 serial=46.npy
#   inflating: Dataset/validation/repetition=8 omega=5  gamma=8 delta=1 serial=47.npy
#   inflating: Dataset/validation/repetition=8 omega=5  gamma=9 delta=1 serial=48.npy
#   inflating: Dataset/validation/repetition=8 omega=6  gamma=1 delta=1 serial=50.npy
#   inflating: Dataset/validation/repetition=8 omega=6  gamma=10 delta=1 serial=59.npy
#   inflating: Dataset/validation/repetition=8 omega=6  gamma=2 delta=1 serial=51.npy
#   inflating: Dataset/validation/repetition=8 omega=6  gamma=3 delta=1 serial=52.npy
#   inflating: Dataset/validation/repetition=8 omega=6  gamma=4 delta=1 serial=53.npy
#   inflating: Dataset/validation/repetition=8 omega=6  gamma=5 delta=1 serial=54.npy
#   inflating: Dataset/validation/repetition=8 omega=6  gamma=6 delta=1 serial=55.npy
#   inflating: Dataset/validation/repetition=8 omega=6  gamma=7 delta=1 serial=56.npy
#   inflating: Dataset/validation/repetition=8 omega=6  gamma=8 delta=1 serial=57.npy
#   inflating: Dataset/validation/repetition=8 omega=6  gamma=9 delta=1 serial=58.npy
#   inflating: Dataset/validation/repetition=8 omega=7  gamma=1 delta=1 serial=60.npy
#   inflating: Dataset/validation/repetition=8 omega=7  gamma=10 delta=1 serial=69.npy
#   inflating: Dataset/validation/repetition=8 omega=7  gamma=2 delta=1 serial=61.npy
#   inflating: Dataset/validation/repetition=8 omega=7  gamma=3 delta=1 serial=62.npy
#   inflating: Dataset/validation/repetition=8 omega=7  gamma=4 delta=1 serial=63.npy
#   inflating: Dataset/validation/repetition=8 omega=7  gamma=5 delta=1 serial=64.npy
#   inflating: Dataset/validation/repetition=8 omega=7  gamma=6 delta=1 serial=65.npy
#   inflating: Dataset/validation/repetition=8 omega=7  gamma=7 delta=1 serial=66.npy
#   inflating: Dataset/validation/repetition=8 omega=7  gamma=8 delta=1 serial=67.npy
#   inflating: Dataset/validation/repetition=8 omega=7  gamma=9 delta=1 serial=68.npy
#   inflating: Dataset/validation/repetition=8 omega=8  gamma=1 delta=1 serial=70.npy
#   inflating: Dataset/validation/repetition=8 omega=8  gamma=10 delta=1 serial=79.npy
#   inflating: Dataset/validation/repetition=8 omega=8  gamma=2 delta=1 serial=71.npy
#   inflating: Dataset/validation/repetition=8 omega=8  gamma=3 delta=1 serial=72.npy
#   inflating: Dataset/validation/repetition=8 omega=8  gamma=4 delta=1 serial=73.npy
#   inflating: Dataset/validation/repetition=8 omega=8  gamma=5 delta=1 serial=74.npy
#   inflating: Dataset/validation/repetition=8 omega=8  gamma=6 delta=1 serial=75.npy
#   inflating: Dataset/validation/repetition=8 omega=8  gamma=7 delta=1 serial=76.npy
#   inflating: Dataset/validation/repetition=8 omega=8  gamma=8 delta=1 serial=77.npy
#   inflating: Dataset/validation/repetition=8 omega=8  gamma=9 delta=1 serial=78.npy
#   inflating: Dataset/validation/repetition=8 omega=9  gamma=1 delta=1 serial=80.npy
#   inflating: Dataset/validation/repetition=8 omega=9  gamma=10 delta=1 serial=89.npy
#   inflating: Dataset/validation/repetition=8 omega=9  gamma=2 delta=1 serial=81.npy
#   inflating: Dataset/validation/repetition=8 omega=9  gamma=3 delta=1 serial=82.npy
#   inflating: Dataset/validation/repetition=8 omega=9  gamma=4 delta=1 serial=83.npy
#   inflating: Dataset/validation/repetition=8 omega=9  gamma=5 delta=1 serial=84.npy
#   inflating: Dataset/validation/repetition=8 omega=9  gamma=6 delta=1 serial=85.npy
#   inflating: Dataset/validation/repetition=8 omega=9  gamma=7 delta=1 serial=86.npy
#   inflating: Dataset/validation/repetition=8 omega=9  gamma=8 delta=1 serial=87.npy
#   inflating: Dataset/validation/repetition=8 omega=9  gamma=9 delta=1 serial=88.npy
#   inflating: Dataset/validation/repetition=9 omega=1  gamma=1 delta=1 serial=0.npy
#   inflating: Dataset/validation/repetition=9 omega=1  gamma=10 delta=1 serial=9.npy
#   inflating: Dataset/validation/repetition=9 omega=1  gamma=2 delta=1 serial=1.npy
#   inflating: Dataset/validation/repetition=9 omega=1  gamma=3 delta=1 serial=2.npy
#   inflating: Dataset/validation/repetition=9 omega=1  gamma=4 delta=1 serial=3.npy
#   inflating: Dataset/validation/repetition=9 omega=1  gamma=5 delta=1 serial=4.npy
#   inflating: Dataset/validation/repetition=9 omega=1  gamma=6 delta=1 serial=5.npy
#   inflating: Dataset/validation/repetition=9 omega=1  gamma=7 delta=1 serial=6.npy
#   inflating: Dataset/validation/repetition=9 omega=1  gamma=8 delta=1 serial=7.npy
#   inflating: Dataset/validation/repetition=9 omega=1  gamma=9 delta=1 serial=8.npy
#   inflating: Dataset/validation/repetition=9 omega=10  gamma=1 delta=1 serial=90.npy
#   inflating: Dataset/validation/repetition=9 omega=10  gamma=10 delta=1 serial=99.npy
#   inflating: Dataset/validation/repetition=9 omega=10  gamma=2 delta=1 serial=91.npy
#   inflating: Dataset/validation/repetition=9 omega=10  gamma=3 delta=1 serial=92.npy
#   inflating: Dataset/validation/repetition=9 omega=10  gamma=4 delta=1 serial=93.npy
#   inflating: Dataset/validation/repetition=9 omega=10  gamma=5 delta=1 serial=94.npy
#   inflating: Dataset/validation/repetition=9 omega=10  gamma=6 delta=1 serial=95.npy
#   inflating: Dataset/validation/repetition=9 omega=10  gamma=7 delta=1 serial=96.npy
#   inflating: Dataset/validation/repetition=9 omega=10  gamma=8 delta=1 serial=97.npy
#   inflating: Dataset/validation/repetition=9 omega=10  gamma=9 delta=1 serial=98.npy
#   inflating: Dataset/validation/repetition=9 omega=2  gamma=1 delta=1 serial=10.npy
#   inflating: Dataset/validation/repetition=9 omega=2  gamma=10 delta=1 serial=19.npy
#   inflating: Dataset/validation/repetition=9 omega=2  gamma=2 delta=1 serial=11.npy
#   inflating: Dataset/validation/repetition=9 omega=2  gamma=3 delta=1 serial=12.npy
#   inflating: Dataset/validation/repetition=9 omega=2  gamma=4 delta=1 serial=13.npy
#   inflating: Dataset/validation/repetition=9 omega=2  gamma=5 delta=1 serial=14.npy
#   inflating: Dataset/validation/repetition=9 omega=2  gamma=6 delta=1 serial=15.npy
#   inflating: Dataset/validation/repetition=9 omega=2  gamma=7 delta=1 serial=16.npy
#   inflating: Dataset/validation/repetition=9 omega=2  gamma=8 delta=1 serial=17.npy
#   inflating: Dataset/validation/repetition=9 omega=2  gamma=9 delta=1 serial=18.npy
#   inflating: Dataset/validation/repetition=9 omega=3  gamma=1 delta=1 serial=20.npy
#   inflating: Dataset/validation/repetition=9 omega=3  gamma=10 delta=1 serial=29.npy
#   inflating: Dataset/validation/repetition=9 omega=3  gamma=2 delta=1 serial=21.npy
#   inflating: Dataset/validation/repetition=9 omega=3  gamma=3 delta=1 serial=22.npy
#   inflating: Dataset/validation/repetition=9 omega=3  gamma=4 delta=1 serial=23.npy
#   inflating: Dataset/validation/repetition=9 omega=3  gamma=5 delta=1 serial=24.npy
#   inflating: Dataset/validation/repetition=9 omega=3  gamma=6 delta=1 serial=25.npy
#   inflating: Dataset/validation/repetition=9 omega=3  gamma=7 delta=1 serial=26.npy
#   inflating: Dataset/validation/repetition=9 omega=3  gamma=8 delta=1 serial=27.npy
#   inflating: Dataset/validation/repetition=9 omega=3  gamma=9 delta=1 serial=28.npy
#   inflating: Dataset/validation/repetition=9 omega=4  gamma=1 delta=1 serial=30.npy
#   inflating: Dataset/validation/repetition=9 omega=4  gamma=10 delta=1 serial=39.npy
#   inflating: Dataset/validation/repetition=9 omega=4  gamma=2 delta=1 serial=31.npy
#   inflating: Dataset/validation/repetition=9 omega=4  gamma=3 delta=1 serial=32.npy
#   inflating: Dataset/validation/repetition=9 omega=4  gamma=4 delta=1 serial=33.npy
#   inflating: Dataset/validation/repetition=9 omega=4  gamma=5 delta=1 serial=34.npy
#   inflating: Dataset/validation/repetition=9 omega=4  gamma=6 delta=1 serial=35.npy
#   inflating: Dataset/validation/repetition=9 omega=4  gamma=7 delta=1 serial=36.npy
#   inflating: Dataset/validation/repetition=9 omega=4  gamma=8 delta=1 serial=37.npy
#   inflating: Dataset/validation/repetition=9 omega=4  gamma=9 delta=1 serial=38.npy
#   inflating: Dataset/validation/repetition=9 omega=5  gamma=1 delta=1 serial=40.npy
#   inflating: Dataset/validation/repetition=9 omega=5  gamma=10 delta=1 serial=49.npy
#   inflating: Dataset/validation/repetition=9 omega=5  gamma=2 delta=1 serial=41.npy
#   inflating: Dataset/validation/repetition=9 omega=5  gamma=3 delta=1 serial=42.npy
#   inflating: Dataset/validation/repetition=9 omega=5  gamma=4 delta=1 serial=43.npy
#   inflating: Dataset/validation/repetition=9 omega=5  gamma=5 delta=1 serial=44.npy
#   inflating: Dataset/validation/repetition=9 omega=5  gamma=6 delta=1 serial=45.npy
#   inflating: Dataset/validation/repetition=9 omega=5  gamma=7 delta=1 serial=46.npy
#   inflating: Dataset/validation/repetition=9 omega=5  gamma=8 delta=1 serial=47.npy
#   inflating: Dataset/validation/repetition=9 omega=5  gamma=9 delta=1 serial=48.npy
#   inflating: Dataset/validation/repetition=9 omega=6  gamma=1 delta=1 serial=50.npy
#   inflating: Dataset/validation/repetition=9 omega=6  gamma=10 delta=1 serial=59.npy
#   inflating: Dataset/validation/repetition=9 omega=6  gamma=2 delta=1 serial=51.npy
#   inflating: Dataset/validation/repetition=9 omega=6  gamma=3 delta=1 serial=52.npy
#   inflating: Dataset/validation/repetition=9 omega=6  gamma=4 delta=1 serial=53.npy
#   inflating: Dataset/validation/repetition=9 omega=6  gamma=5 delta=1 serial=54.npy
#   inflating: Dataset/validation/repetition=9 omega=6  gamma=6 delta=1 serial=55.npy
#   inflating: Dataset/validation/repetition=9 omega=6  gamma=7 delta=1 serial=56.npy
#   inflating: Dataset/validation/repetition=9 omega=6  gamma=8 delta=1 serial=57.npy
#   inflating: Dataset/validation/repetition=9 omega=6  gamma=9 delta=1 serial=58.npy
#   inflating: Dataset/validation/repetition=9 omega=7  gamma=1 delta=1 serial=60.npy
#   inflating: Dataset/validation/repetition=9 omega=7  gamma=10 delta=1 serial=69.npy
#   inflating: Dataset/validation/repetition=9 omega=7  gamma=2 delta=1 serial=61.npy
#   inflating: Dataset/validation/repetition=9 omega=7  gamma=3 delta=1 serial=62.npy
#   inflating: Dataset/validation/repetition=9 omega=7  gamma=4 delta=1 serial=63.npy
#   inflating: Dataset/validation/repetition=9 omega=7  gamma=5 delta=1 serial=64.npy
#   inflating: Dataset/validation/repetition=9 omega=7  gamma=6 delta=1 serial=65.npy
#   inflating: Dataset/validation/repetition=9 omega=7  gamma=7 delta=1 serial=66.npy
#   inflating: Dataset/validation/repetition=9 omega=7  gamma=8 delta=1 serial=67.npy
#   inflating: Dataset/validation/repetition=9 omega=7  gamma=9 delta=1 serial=68.npy
#   inflating: Dataset/validation/repetition=9 omega=8  gamma=1 delta=1 serial=70.npy
#   inflating: Dataset/validation/repetition=9 omega=8  gamma=10 delta=1 serial=79.npy
#   inflating: Dataset/validation/repetition=9 omega=8  gamma=2 delta=1 serial=71.npy
#   inflating: Dataset/validation/repetition=9 omega=8  gamma=3 delta=1 serial=72.npy
#   inflating: Dataset/validation/repetition=9 omega=8  gamma=4 delta=1 serial=73.npy
#   inflating: Dataset/validation/repetition=9 omega=8  gamma=5 delta=1 serial=74.npy
#   inflating: Dataset/validation/repetition=9 omega=8  gamma=6 delta=1 serial=75.npy
#   inflating: Dataset/validation/repetition=9 omega=8  gamma=7 delta=1 serial=76.npy
#   inflating: Dataset/validation/repetition=9 omega=8  gamma=8 delta=1 serial=77.npy
#   inflating: Dataset/validation/repetition=9 omega=8  gamma=9 delta=1 serial=78.npy
#   inflating: Dataset/validation/repetition=9 omega=9  gamma=1 delta=1 serial=80.npy
#   inflating: Dataset/validation/repetition=9 omega=9  gamma=10 delta=1 serial=89.npy
#   inflating: Dataset/validation/repetition=9 omega=9  gamma=2 delta=1 serial=81.npy
#   inflating: Dataset/validation/repetition=9 omega=9  gamma=3 delta=1 serial=82.npy
#   inflating: Dataset/validation/repetition=9 omega=9  gamma=4 delta=1 serial=83.npy
#   inflating: Dataset/validation/repetition=9 omega=9  gamma=5 delta=1 serial=84.npy
#   inflating: Dataset/validation/repetition=9 omega=9  gamma=6 delta=1 serial=85.npy
#   inflating: Dataset/validation/repetition=9 omega=9  gamma=7 delta=1 serial=86.npy
#   inflating: Dataset/validation/repetition=9 omega=9  gamma=8 delta=1 serial=87.npy
#   inflating: Dataset/validation/repetition=9 omega=9  gamma=9 delta=1 serial=88.npy

# %%
import matplotlib as plt

# %%
# Defining the path to the relevant data
path_to_training_data = '/content/Dataset/training'
path_to_validation_data = '/content/Dataset/validation'

# %%
# Generating a list of the files in the directory using glob

import glob

filelist = glob.glob(path_to_training_data+'/*.npy')

#print the first 10 entries:
filelist[1:10]
# Out:
# ['/content/Dataset/training/repetition=81 omega=1  gamma=7 delta=1 serial=6.npy',
#  '/content/Dataset/training/repetition=79 omega=2  gamma=1 delta=1 serial=10.npy',
#  '/content/Dataset/training/repetition=63 omega=5  gamma=10 delta=1 serial=49.npy',
#  '/content/Dataset/training/repetition=18 omega=5  gamma=7 delta=1 serial=46.npy',
#  '/content/Dataset/training/repetition=52 omega=9  gamma=4 delta=1 serial=83.npy',
#  '/content/Dataset/training/repetition=60 omega=10  gamma=4 delta=1 serial=93.npy',
#  '/content/Dataset/training/repetition=34 omega=4  gamma=8 delta=1 serial=37.npy',
#  '/content/Dataset/training/repetition=36 omega=3  gamma=8 delta=1 serial=27.npy',
#  '/content/Dataset/training/repetition=85 omega=4  gamma=10 delta=1 serial=39.npy']

# %%
# activating the autoloader
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Importing the dataloader

# %%
from dataloader import CustomDataset

# %%
training_ds = CustomDataset(path_to_training_data, transform=True)
validation_ds = CustomDataset(path_to_validation_data)

some_random_idx = 30
training_ds[some_random_idx]
# Out:
# (tensor([[0.0000e+00, 4.9000e-05, 1.9424e-04,  ..., 4.5402e-01, 4.5465e-01,
#           4.5527e-01],
#          [0.0000e+00, 4.9000e-05, 1.9424e-04,  ..., 4.5402e-01, 4.5465e-01,
#           4.5527e-01],
#          [0.0000e+00, 4.9000e-05, 1.9424e-04,  ..., 4.5402e-01, 4.5465e-01,
#           4.5527e-01]], dtype=torch.float64),
#  tensor(68))

# %% [markdown]
# ## Creating the dataloader

# %%
from torch.utils.data import Dataset, DataLoader

training_dataloader = DataLoader(training_ds,batch_size=300,shuffle=True)
valid_dataloader = DataLoader(validation_ds,batch_size=300)

# %%
# check
for x,y in training_dataloader:
    print(x.shape, y.shape)
    break
# Out:
# torch.Size([300, 3, 5000]) torch.Size([300])

# %% [markdown]
# # Importing the nerual network

# %%
from model import CNN_Net

# %%
net = CNN_Net()

# %%
# checking the size of our model
z=net(x.float())
print(z)
# Out:
# tensor([[ 0.0045,  0.0141, -0.0102,  ..., -0.0055,  0.0022,  0.0024],
#         [ 0.0047,  0.0142, -0.0103,  ..., -0.0054,  0.0022,  0.0022],
#         [ 0.0047,  0.0141, -0.0102,  ..., -0.0055,  0.0022,  0.0022],
#         ...,
#         [ 0.0046,  0.0142, -0.0103,  ..., -0.0055,  0.0022,  0.0022],
#         [ 0.0047,  0.0141, -0.0102,  ..., -0.0056,  0.0022,  0.0022],
#         [ 0.0045,  0.0141, -0.0102,  ..., -0.0056,  0.0021,  0.0022]],
#        grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## Training

# %%
import torch
import torch.nn as nn
import torch.optim as optim


loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %%
def compute_accuracy_and_loss(dataloader,net):
    total = 0
    correct = 0
    loss = 0

    if torch.cuda.is_available():
        net.cuda()
    net.eval()

    n_batches = 0
    with torch.no_grad():
        for x,y in dataloader:
            n_batches+=1

            if torch.cuda.is_available():
                x = x.cuda()
                y = y.cuda()

            pred = net(x.float())

            loss+= loss_func(pred, y).item()

            pred = torch.argmax(pred,dim=1)

            correct+=len(torch.where((pred==y))[0])
            total+=len(y)

    loss = loss/n_batches

    return correct/total, loss

# %%
#net.load_state_dict(torch.load('/content/drive/MyDrive/GitHub/Project_CNN/trained_model.pt',map_location='cpu'))

# %%
#net.eval()
#net.cpu()
# predicted = net( x.unsqueeze(1) )[0][0].data.numpy()

# %%
compute_accuracy_and_loss(training_dataloader,net)
# Out:
# (0.01, 4.605165579739739)

# %%
compute_accuracy_and_loss(valid_dataloader,net)
# Out:
# (0.01, 4.605180291568532)

# %%
if torch.cuda.is_available():
    net.cuda()

# %%
from tqdm.notebook import tqdm
import time

n_epochs = 100

t0=time.time()
training_loss_vs_epoch = []
validation_loss_vs_epoch = []

training_acc_vs_epoch = []
validation_acc_vs_epoch = []

pbar = tqdm(range(n_epochs))

for epoch in pbar:
    t1=round((time.time()-t0)/60)
    if len(training_loss_vs_epoch) > 1:
        pbar.set_description('val acc:'+'{0:.5f}'.format(validation_acc_vs_epoch[-1])+
        ', train acc:'+'{0:.5f}'.format(training_acc_vs_epoch[-1]))
        print(epoch, 'train loss',training_loss_vs_epoch[-1],'acc', (training_acc_vs_epoch[-1]),' Time: ', round(t1))

    net.train() # put the net into "training mode"

    for x,y in training_dataloader:
        if torch.cuda.is_available():
            x = x.cuda()
            y = y.cuda()

        optimizer.zero_grad()
        output = net(x.float())
        loss = loss_func(output,y)
        loss.backward()
        optimizer.step()


    net.eval() #put the net into evaluation mode


    train_acc, train_loss = compute_accuracy_and_loss(training_dataloader,net)
    valid_acc, valid_loss =  compute_accuracy_and_loss(valid_dataloader,net)

    training_loss_vs_epoch.append(train_loss)
    training_acc_vs_epoch.append(train_acc)

    validation_acc_vs_epoch.append(valid_acc)

    validation_loss_vs_epoch.append(valid_loss)

    #save the model if the validation loss has decreased
    # if len(validation_loss_vs_epoch)==1 or validsation_loss_vs_epoch[-2] > validation_loss_vs_epoch[-1]:
    #     torch.save(net.state_dict(), '/content/gdrive/MyDrive/Deep_learning/Lesson 1/HW1/trained_model.pt')
    if len(validation_loss_vs_epoch)==1 or validation_loss_vs_epoch[-2] > validation_loss_vs_epoch[-1]:
        torch.save(net.state_dict(), '/content/drive/MyDrive/GitHub/Project_CNN/trained_model_2024.pt')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 2 train loss 3.1122840081944183 acc 0.1717  Time:  2
# 3 train loss 2.669020975337309 acc 0.2466  Time:  2
# 4 train loss 2.08891581437167 acc 0.3676  Time:  3
# 5 train loss 1.48867447236005 acc 0.5365  Time:  4
# 6 train loss 1.2126059321796192 acc 0.637  Time:  5
# 7 train loss 0.8820349346188938 acc 0.7351  Time:  6
# 8 train loss 0.931664096958497 acc 0.6942  Time:  7
# 9 train loss 0.5311937069191652 acc 0.8122  Time:  7
# 10 train loss 0.4771258866085726 acc 0.8246  Time:  8
# 11 train loss 0.3853624287773581 acc 0.855  Time:  9
# 12 train loss 0.30499106251141606 acc 0.898  Time:  10
# 13 train loss 0.3065701692419894 acc 0.8877  Time:  11
# 14 train loss 0.4261603294049992 acc 0.8751  Time:  12
# 15 train loss 0.3961397326167892 acc 0.9202  Time:  12
# 16 train loss 0.1663550815599806 acc 0.9387  Time:  13
# 17 train loss 0.12890746378723314 acc 0.9443  Time:  14
# 18 train loss 0.08449224360725459 acc 0.9591  Time:  15
# 19 train loss 0.3064525767284281 acc 0.905  Time:  16
# 20 train loss 0.09567681119284209 acc 0.9617  Time:  16
# 21 train loss 0.10611936406177633 acc 0.9457  Time:  17
# 22 train loss 0.12279229129061979 acc 0.9501  Time:  18
# 23 train loss 0.1368196218767587 acc 0.9463  Time:  19
# 24 train loss 0.05674988655921291 acc 0.9906  Time:  20
# 25 train loss 0.15806633299764464 acc 0.9551  Time:  20
# 26 train loss 0.07821477029253454 acc 0.9906  Time:  21
# 27 train loss 0.09231354241423748 acc 0.9794  Time:  22
# 28 train loss 0.08201100228025633 acc 0.9764  Time:  23
# 29 train loss 0.12014386507079881 acc 0.9592  Time:  24
# 30 train loss 0.07003236452446264 acc 0.9663  Time:  25
# 31 train loss 0.039896377526661926 acc 0.9959  Time:  25
# 32 train loss 0.027990121161565185 acc 0.9893  Time:  26
# 33 train loss 0.08911067532265887 acc 0.968  Time:  27
# 34 train loss 0.04230158228208037 acc 0.9853  Time:  28
# 35 train loss 0.010951401453520008 acc 0.9999  Time:  29
# 36 train loss 0.00947637138340403 acc 0.9996  Time:  30
# 37 train loss 0.22623003975433462 acc 0.9108  Time:  30
# 38 train loss 0.06442141258979545 acc 0.9857  Time:  31
# 39 train loss 0.0356744217193302 acc 0.9962  Time:  32
# 40 train loss 0.014815744752173914 acc 0.9991  Time:  33
# 41 train loss 0.013146106098942897 acc 0.9995  Time:  34
# 42 train loss 1.4337674204040975 acc 0.7328  Time:  34
# 43 train loss 0.09980140319641899 acc 0.9662  Time:  35
# 44 train loss 0.023845612071454525 acc 0.9973  Time:  36
# 45 train loss 0.009254881454741253 acc 1.0  Time:  37
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-2768e181a6b9> in <cell line: 15>()
#      37
#      38
# ---> 39     train_acc, train_loss = compute_accuracy_and_loss(training_dataloader,net)
#      40     valid_acc, valid_loss =  compute_accuracy_and_loss(valid_dataloader,net)
#      41
#
# <ipython-input-22-bce05dfd6f08> in compute_accuracy_and_loss(dataloader, net)
#      19             pred = net(x.float())
#      20
# ---> 21             loss+= loss_func(pred, y).item()
#      22
#      23             pred = torch.argmax(pred,dim=1)
#
# KeyboardInterrupt:

# %%
# Loading a pretrained net
# net.load_state_dict(torch.load('/content/drive/MyDrive/Deep_learning/Lesson 2/HW2-part2/trained_model1.pt',map_location='cpu'))

# %%
# plotting the result

import matplotlib.pyplot as plt

fig,ax = plt.subplots(1,2,figsize=(8,3))

ax[0].plot(training_loss_vs_epoch,label='training')
ax[0].plot(validation_loss_vs_epoch,label='validation')
ax[0].set_xlim([0, 45])
ax[0].set_title('Loss vs. epoch')
ax[0].legend()

ax[1].plot(training_acc_vs_epoch,label='training')
ax[1].plot(validation_acc_vs_epoch,label='validation')
ax[1].set_xlim([0, 45])
ax[1].set_title('Accuracy vs. epoch')
ax[1].legend()

plt.show()
